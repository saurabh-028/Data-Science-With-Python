# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("k_circle_sales.csv")
# another approach
# data=pd.read_csv("C:\Users\User\OneDrive\Desktop\Simplilearn _assignment\k_circle_sales.csv")

# %%
# import os
# os.getcwd()
# Out:
# '/home/labsuser'

# %%
data.shape
# Out:
# (8523, 13)

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
data.head(3)# display first 5 rows
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0     249.8            OUT049                       1999      Medium
# 1      48.3            OUT018                       2009      Medium
# 2     141.6            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  Profit
# 0               Tier 2  Supermarket Type1          3735.1380    11.5
# 1               Tier 2  Supermarket Type2           443.4228    14.3
# 2               Tier 2  Supermarket Type1          2097.2700    14.5

# %%
data.tail()# display last 5 rows
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods     214.5            OUT013
# 8519        Baking Goods     108.2            OUT045
# 8520  Health and Hygiene      85.1            OUT035
# 8521         Snack Foods     103.1            OUT018
# 8522         Soft Drinks      75.5            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN                  NaN
# ...

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# Profit                       float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7775 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       6473 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  Profit                     8523 non-null   float64
# ...

# %%
data.columns # columns present in the data
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Profit'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
data.describe(include="all")
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7775.000000      8523.000000  8523.000000                8523.000000
# mean     11.688100         0.066132   140.998838                1997.831867
# std       5.862684         0.051598    62.258099                   8.371760
# min       0.000000         0.000000    31.300000                1985.000000
# 25%       7.720000         0.026989    93.800000                1987.000000
# 50%      11.800000         0.053931   142.700000                1999.000000
# 75%      16.500000         0.094585   185.650000                2004.000000
# max     100.000000         0.328391   266.900000                2009.000000
#
#        Item_Outlet_Sales       Profit
# count        8523.000000  8523.000000
# mean         2181.288914    13.414514
# std          1706.499616     1.701840
# min            33.290000     0.100000
# 25%           834.247400    13.150000
# 50%          1794.331000    13.900000
# ...

# %%
data.describe(include="all")
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7775.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDG33          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    11.688100              NaN         0.066132
# std                NaN     5.862684              NaN         0.051598
# min                NaN     0.000000              NaN         0.000000
# 25%                NaN     7.720000              NaN         0.026989
# 50%                NaN    11.800000              NaN         0.053931
# 75%                NaN    16.500000              NaN         0.094585
# max                NaN   100.000000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# ...

# %%
data.isnull().any()# checking the null values
# Out:
# Item_Identifier              False
# Item_Weight                   True
# Item_Fat_Content             False
# Item_Visibility              False
# Item_Type                    False
# Item_MRP                     False
# Outlet_Identifier            False
# Outlet_Establishment_Year    False
# Outlet_Size                   True
# Outlet_Location_Type          True
# Outlet_Type                  False
# Item_Outlet_Sales            False
# Profit                       False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   748
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Profit                          0
# dtype: int64

# %%
data1=data

# %%
d=data1.dropna()

# %%
d.shape
# Out:
# (5365, 13)

# %%
data.fillna(value=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Profit                       0
# dtype: int64

# %%
data["Item_Fat_Content"].nunique() # find no.of various object in the column
# Out:
# 5

# %%
data["Item_Fat_Content"].unique() # what are the variou sobject
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
data["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
data["Item_Fat_Content"].value_counts().to_frame()
# Out:
#          Item_Fat_Content
# Low Fat              5089
# Regular              2889
# LF                    316
# reg                   117
# low fat               112

# %%
data2=data.drop("Item_Identifier",axis=1)  # axis= 0 row # axis=1   column

# %%
data2.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales', 'Profit'],
#       dtype='object')

# %%
data2=data.drop(["Item_Weight","Outlet_Establishment_Year"],axis=1)

# %%
data2.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Profit'],
#       dtype='object')

# %%
data2.shape
# Out:
# (8523, 11)

# %%
data2=data2.drop([15,30])

# %%
data2.shape
# Out:
# (8521, 11)

# %%
# Slicing/indexing

# %%
data["Item_Fat_Content"]# accessin a one column
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
data[["Item_Fat_Content",'Item_Outlet_Sales', 'Profit']] # multiple columns data to passed inside the lsit
# Out:
#      Item_Fat_Content  Item_Outlet_Sales  Profit
# 0             Low Fat          3735.1380    11.5
# 1             Regular           443.4228    14.3
# 2             Low Fat          2097.2700    14.5
# 3             Regular           732.3800    13.6
# 4             Low Fat           994.7052    14.1
# ...               ...                ...     ...
# 8518          Low Fat          2778.3834    14.1
# 8519          Regular           549.2850    14.2
# 8520          Low Fat          1193.1136     9.5
# 8521          Regular          1845.5976    14.2
# 8522          Low Fat           765.6700    14.6
#
# [8523 rows x 3 columns]

# %%
# access first 10 rows using loc
data.loc[0:9,:]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10        0.000          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy     249.8            OUT049
# 1            Soft Drinks      48.3            OUT018
# 2                   Meat     141.6            OUT049
# ...

# %%
#using loc display 10 rows from item weight to item MRP
data.loc[0:9,"Item_Weight":"Item_MRP"]
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0        9.300          Low Fat         0.016047                  Dairy
# 1        5.920          Regular         0.019278            Soft Drinks
# 2       17.500          Low Fat         0.016760                   Meat
# 3       19.200          Regular         0.000000  Fruits and Vegetables
# 4        8.930          Low Fat         0.000000              Household
# 5       10.395          Regular         0.000000           Baking Goods
# 6       13.650          Regular         0.012741            Snack Foods
# 7        0.000          Low Fat         0.127470            Snack Foods
# 8       16.200          Regular         0.016687           Frozen Foods
# 9       19.200          Regular         0.094450           Frozen Foods
#
#    Item_MRP
# 0     249.8
# 1      48.3
# 2     141.6
# 3     182.1
# 4      53.9
# 5      51.4
# 6      57.7
# 7     107.8
# 8      97.0
# 9     187.8

# %%
data.loc[0:9,["Item_Weight","Item_MRP","Profit"]]
# Out:
#    Item_Weight  Item_MRP  Profit
# 0        9.300     249.8    11.5
# 1        5.920      48.3    14.3
# 2       17.500     141.6    14.5
# 3       19.200     182.1    13.6
# 4        8.930      53.9    14.1
# 5       10.395      51.4     9.5
# 6       13.650      57.7     8.8
# 7        0.000     107.8    13.3
# 8       16.200      97.0    13.0
# 9       19.200     187.8    13.6

# %%
#using iloc display 20 rows from item weight to item MRP
data.iloc[:20,1:6]
# Out:
#     Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.300          Low Fat         0.016047                  Dairy
# 1         5.920          Regular         0.019278            Soft Drinks
# 2        17.500          Low Fat         0.016760                   Meat
# 3        19.200          Regular         0.000000  Fruits and Vegetables
# 4         8.930          Low Fat         0.000000              Household
# 5        10.395          Regular         0.000000           Baking Goods
# 6        13.650          Regular         0.012741            Snack Foods
# 7         0.000          Low Fat         0.127470            Snack Foods
# 8        16.200          Regular         0.016687           Frozen Foods
# 9        19.200          Regular         0.094450           Frozen Foods
# 10       11.800          Low Fat         0.000000  Fruits and Vegetables
# 11       18.500          Regular         0.045464                  Dairy
# ...

# %%
data.iloc[:20,[1,5,12]]
# Out:
#     Item_Weight  Item_MRP  Profit
# 0         9.300     249.8    11.5
# 1         5.920      48.3    14.3
# 2        17.500     141.6    14.5
# 3        19.200     182.1    13.6
# 4         8.930      53.9    14.1
# 5        10.395      51.4     9.5
# 6        13.650      57.7     8.8
# 7         0.000     107.8    13.3
# 8        16.200      97.0    13.0
# 9        19.200     187.8    13.6
# 10       11.800      45.5    14.3
# 11       18.500     144.1    14.3
# 12       15.100     145.5    14.6
# 13       17.600     119.7    14.1
# 14       16.350     196.4    13.5
# 15        9.000      56.4    13.0
# 16       11.800     115.3     8.6
# 17        9.000      54.4    14.8
# 18        0.000     113.3    14.4
# 19       13.350     230.5    14.0

# %%
#1,5,8 rows and  item weight,i tem mrp,profit using iloc
data.iloc[[1,5,8],[1,5,12]]
# Out:
#    Item_Weight  Item_MRP  Profit
# 1        5.920      48.3    14.3
# 5       10.395      51.4     9.5
# 8       16.200      97.0    13.0

# %%
# sorting
data.sort_values(by=["Item_Weight"],ascending=False).head(5)  # decending
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 229            FDX25       100.00          Low Fat         0.101562    Canned
# 4468           FDC02        21.35          Low Fat         0.068822    Canned
# 2368           FDC02        21.35          Low Fat         0.068809    Canned
# 2802           FDC02        21.35          Low Fat         0.068765    Canned
# 43             FDC02        21.35          Low Fat         0.069103    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 229      181.9            OUT027                       1985      Medium
# 4468     258.3            OUT046                       1997       Small
# 2368     258.5            OUT035                       2004       Small
# 2802     260.4            OUT013                       1987        High
# 43       259.9            OUT018                       2009      Medium
#
# ...

# %%
data.sort_values(by=["Item_Weight","Item_MRP"],ascending=[False,False]).head(10)  # decending
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 229            FDX25       100.00          Low Fat         0.101562
# 2802           FDC02        21.35          Low Fat         0.068765
# 43             FDC02        21.35          Low Fat         0.069103
# 2368           FDC02        21.35          Low Fat         0.068809
# 483            FDC02        21.35          Low Fat         0.115195
# 4468           FDC02        21.35          Low Fat         0.068822
# 4257           FDR07        21.35          Low Fat         0.130127
# 6389           FDR07        21.35          Low Fat         0.078061
# 7158           NCX17        21.25          Low Fat         0.114066
# 7042           NCX17        21.25          Low Fat         0.113834
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 229                  Canned     181.9            OUT027
# 2802                 Canned     260.4            OUT013
# ...

# %%
data.sort_values(by=["Item_Weight","Item_MRP","Profit"],ascending=[False,True,False]).head(5)  # decending
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 229            FDX25       100.00          Low Fat         0.101562
# 6389           FDR07        21.35          Low Fat         0.078061
# 4257           FDR07        21.35          Low Fat         0.130127
# 483            FDC02        21.35          Low Fat         0.115195
# 4468           FDC02        21.35          Low Fat         0.068822
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 229                  Canned     181.9            OUT027
# 6389  Fruits and Vegetables      96.0            OUT018
# 4257  Fruits and Vegetables      96.2            OUT010
# 483                  Canned     258.3            OUT010
# 4468                 Canned     258.3            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 229                        1985      Medium               Tier 2
# 6389                       2009      Medium               Tier 2
# ...

# %%
data.sort_values(by=["Item_Weight","Item_MRP"],ascending=[True,True]).head(10)  # decending
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 153            DRK12          0.0          Low Fat         0.041683
# 2242           FDG40          0.0          Low Fat         0.039631
# 2518           FDU21          0.0          Regular         0.076349
# 952            FDX59          0.0          Low Fat         0.051411
# 7943           NCE31          0.0          Low Fat         0.183948
# 867            FDJ45          0.0          Low Fat         0.073055
# 6986           FDJ45          0.0          Low Fat         0.128533
# 3053           NCL41          0.0          Low Fat         0.073077
# 7612           FDS40          0.0          Low Fat         0.024546
# 6291           NCO06          0.0          Low Fat         0.107507
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 153          Soft Drinks      31.3            OUT027
# 2242        Frozen Foods      32.0            OUT027
# 2518         Snack Foods      32.9            OUT027
# ...

# %%
# filtering
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy     249.8            OUT049
# 1            Soft Drinks      48.3            OUT018
# 2                   Meat     141.6            OUT049
# 3  Fruits and Vegetables     182.1            OUT010
# 4              Household      53.9            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 2
# 1                       2009      Medium               Tier 2
# ...

# %%
#find the item type,mrp when item weight is <10
df2=data.loc[data["Item_Weight"]<10,["Item_Type","Item_Fat_Content","Item_MRP"]]
df2
# Out:
#                   Item_Type Item_Fat_Content  Item_MRP
# 0                     Dairy          Low Fat     249.8
# 1               Soft Drinks          Regular      48.3
# 4                 Household          Low Fat      53.9
# 7               Snack Foods          Low Fat     107.8
# 15                Breakfast          Regular      56.4
# ...                     ...              ...       ...
# 8507           Frozen Foods          Regular     101.8
# 8509  Fruits and Vegetables          Low Fat     214.0
# 8518            Snack Foods          Low Fat     214.5
# 8519           Baking Goods          Regular     108.2
# 8521            Snack Foods          Regular     103.1
#
# [3839 rows x 3 columns]

# %%
# find MRP for Low Fat content
df2 = data.loc[data['Item_Fat_Content']==('LF' and 'Low Fat'), ['Item_Type', 'Item_Fat_Content', 'Item_MRP']].head(100)
df2
# Out:
#                  Item_Type Item_Fat_Content  Item_MRP
# 0                    Dairy          Low Fat     249.8
# 2                     Meat          Low Fat     141.6
# 4                Household          Low Fat      53.9
# 7              Snack Foods          Low Fat     107.8
# 10   Fruits and Vegetables          Low Fat      45.5
# ..                     ...              ...       ...
# 154  Fruits and Vegetables          Low Fat     226.2
# 155              Household          Low Fat     223.6
# 157              Breakfast          Low Fat      99.8
# 158            Soft Drinks          Low Fat     140.9
# 161  Fruits and Vegetables          Low Fat      97.0
#
# [100 rows x 3 columns]

# %%
#Groupby

dat=pd.DataFrame({"Gender":["m","f","m","m","f"],"Age":[25,56,78,29,60],"height":[5.2,7,5.9,6.8,6]})
dat
# Out:
#   Gender  Age  height
# 0      m   25     5.2
# 1      f   56     7.0
# 2      m   78     5.9
# 3      m   29     6.8
# 4      f   60     6.0

# %%
dat.groupby("Gender").mean()
# Out:
#         Age    height
# Gender
# f        58  6.500000
# m        44  5.966667

# %%
data1=data.dropna()

# %%
data1.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Profit                       0
# dtype: int64

# %%
data1.shape
# Out:
# (5365, 13)

# %%
data1.groupby("Outlet_Location_Type")["Item_Outlet_Sales"].sum()
# Out:
# Outlet_Location_Type
# Tier 2    5.741296e+06
# Tier 3    2.142664e+06
# Tier1     4.476998e+06
# Name: Item_Outlet_Sales, dtype: float64

# %%
outlet_obj=data1.groupby("Outlet_Location_Type")

# %%
outlet_obj.get_group("Tier1")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 11             FDA03        18.50          Regular         0.045464
# 13             FDS46        17.60          Regular         0.047257
# 15             FDP49         9.00          Regular         0.069089
# 19             FDU02        13.35          Low Fat         0.102492
# 22             NCB30        14.60          Low Fat         0.025698
# ...              ...          ...              ...              ...
# 8510           FDN58        13.80          Regular         0.056862
# 8513           FDH31        12.00          Regular         0.020407
# 8517           FDF53        20.75              reg         0.083607
# 8520           NCJ29        10.60          Low Fat         0.035186
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 11                 Dairy     144.1            OUT046
# ...

# %%
#find the average total outlet sale with item type and outlet size
sale=data1.groupby(["Item_Type","Outlet_Size"])["Item_Outlet_Sales"].mean()
sale
# Out:
# Item_Type              Outlet_Size
# Baking Goods           High           2050.901134
#                        Medium         2153.144743
#                        Small          1915.790783
# Breads                 High           2080.731528
#                        Medium         2522.626764
#                        Small          2379.981362
# Breakfast              High           2104.286508
#                        Medium         2439.969744
#                        Small          1840.789044
# Canned                 High           2211.265203
#                        Medium         2296.065843
#                        Small          2210.013439
# Dairy                  High           2453.181713
#                        Medium         2412.833451
#                        Small          2131.795386
# Frozen Foods           High           2214.096189
#                        Medium         2412.450166
#                        Small          2063.397055
# ...

# %%
sale.reset_index()
# Out:
#                 Item_Type Outlet_Size  Item_Outlet_Sales
# 0            Baking Goods        High        2050.901134
# 1            Baking Goods      Medium        2153.144743
# 2            Baking Goods       Small        1915.790783
# 3                  Breads        High        2080.731528
# 4                  Breads      Medium        2522.626764
# 5                  Breads       Small        2379.981362
# 6               Breakfast        High        2104.286508
# 7               Breakfast      Medium        2439.969744
# 8               Breakfast       Small        1840.789044
# 9                  Canned        High        2211.265203
# 10                 Canned      Medium        2296.065843
# 11                 Canned       Small        2210.013439
# 12                  Dairy        High        2453.181713
# 13                  Dairy      Medium        2412.833451
# 14                  Dairy       Small        2131.795386
# ...
